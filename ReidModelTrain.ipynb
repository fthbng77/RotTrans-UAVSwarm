# %%
# !pip install timm yacs opencv-python

# %%
import torch
import torchvision
import timm
import yacs
import cv2

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Torchvision:", torchvision.__version__)
print("Timm:", timm.__version__)
print("OpenCV:", cv2.__version__)

# %%
from getpass import getpass

token = getpass("GitHub token: ")
repo_url = f"https://{token}@github.com/fthbng77/RotTrans-UAVSwarm.git"

# !git clone {repo_url}

# %%
# %cd RotTrans-UAVSwarm

# %%
# !ls

# %%
# !find . -maxdepth 2 -type f

# %%
import os
import torch

# Download DeiT-Small pretrained weights to ~/.cache/torch/checkpoints/
model = torch.hub.load('facebookresearch/deit:main', 'deit_small_patch16_224', pretrained=True)

cache_dir = os.path.expanduser("~/.cache/torch/checkpoints")
os.makedirs(cache_dir, exist_ok=True)
save_path = os.path.join(cache_dir, "deit_small_patch16_224.pth")
torch.save(model.state_dict(), save_path)

print(f"Saved. Size: {os.path.getsize(save_path)/1e6:.1f}MB")
print(f"Path: {save_path}")

# %%
import os

path = os.path.expanduser('~/.cache/torch/checkpoints/deit_small_patch16_224.pth')
print(path)
print(os.path.exists(path))

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.makedirs('/content/drive/MyDrive/rottrans_out', exist_ok=True)

# %%
# !python train.py \
  --config_file configs/UAV-Swarm/vit_transreid_stride_384.yml \
  OUTPUT_DIR /content/drive/MyDrive/rottrans_out
